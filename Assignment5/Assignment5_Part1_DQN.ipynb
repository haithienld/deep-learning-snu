# %% [markdown]
# # M2177.003100 Deep Learning <br>Assignment #5 Part 1: Implementing and Training a Deep Q-Network

# %% [markdown]
# Copyright (C) Data Science Laboratory, Seoul National University. This material is for educational uses only. Some contents are based on the material provided by other paper/book authors and may be copyrighted by them. Written by Hyungyu Lee, November 2019

# %% [markdown]
# In this notebook, you will implement one of famous reinforcement learning algorithm, Deep Q-Network (DQN) of DeepMind. <br>
# The goal here is to understand a basic form of DQN [1, 2] and learn how to use OpenAI Gym toolkit [3].<br>
# You need to follow the instructions to implement the given classes.
#
# 1. [Play](#play) ( 50 points )
#
# **Note**: certain details are missing or ambiguous on purpose, in order to test your knowledge on the related materials. However, if you really feel that something essential is missing and cannot proceed to the next step, then contact the teaching staff with clear description of your problem.
#
# ### Submitting your work:
# <font color=red>**DO NOT clear the final outputs**</font> so that TAs can grade both your code and results.
# Once you have done **two parts of the assignment**, run the *CollectSubmission.sh* script with your **Team number** as input argument. <br>
# This will produce a zipped file called *[Your team number].tar.gz*. Please submit this file on ETL. &nbsp;&nbsp; (Usage: ./*CollectSubmission.sh* &nbsp; Team_#)
#
# ### Some helpful references for assignment #4 :
# - [1] Mnih, Volodymyr, et al. "Playing atari with deep reinforcement learning." arXiv preprint arXiv:1312.5602 (2013). [[pdf]](https://www.google.co.kr/url?sa=t&rct=j&q=&esrc=s&source=web&cd=3&cad=rja&uact=8&ved=0ahUKEwiI3aqPjavVAhXBkJQKHZsIDpgQFgg7MAI&url=https%3A%2F%2Fwww.cs.toronto.edu%2F~vmnih%2Fdocs%2Fdqn.pdf&usg=AFQjCNEd1AJoM72DeDpI_GBoPuv7NnVoFA)
# - [2] Mnih, Volodymyr, et al. "Human-level control through deep reinforcement learning." Nature 518.7540 (2015): 529-533. [[pdf]](https://www.nature.com/nature/journal/v518/n7540/pdf/nature14236.pdf)
# - [3] OpenAI GYM website [[link]](https://gym.openai.com/envs) and [[git]](https://github.com/openai/gym)

# %% [markdown]
# ## 0. OpenAI Gym
#
# OpenAI Gym is a toolkit to support diverse environments for developing reinforcement learning algorithms. You can use the toolkit with Python as well as TensorFlow. Installation guide of OpenAI Gym is offered by [this link](https://github.com/openai/gym#installation) or just type the command "pip install gym" (as well as "pip install gym[atari]" for Part2).
#
# After you set up OpenAI Gym, you can use APIs of the toolkit by inserting <font color=red>import gym</font> into your code. In this assignment, you must build one of famous reinforcement learning algorithms whose agent can run on OpenAI Gym environments. Please check how to use APIs such as funcions interacting with environments in the followings.

# %%
import tensorflow as tf
import cv2 
import gym
import numpy as np
import os
import argparse
import sys
import math
import matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Make an environment instance of CartPole-v0.
env = gym.make('CartPole-v0')

# Before interacting with the environment and starting a new episode, you must reset the environment's state.
state = env.reset()

#rendering game screens, do not need for assignment evaluation
# env.render() 

# You can check action space and state (observation) space.
num_actions = env.action_space.n
state_shape = env.observation_space.shape
print(num_actions)
print(state_shape)

# "step" function performs agent's actions given current state of the environment and returns several values.
# Input: action (numerical data)
#        - env.action_space.sample(): select a random action among possible actions.
# Output: next_state (numerical data, next state of the environment after performing given action)
#         reward (numerical data, reward of given action given current state)
#         terminal (boolean data, True means the agent is done in the environment)
next_state, reward, terminal, info = env.step(env.action_space.sample())
# Out:
# [2019-12-04 17:37:01,316] Making new env: CartPole-v0
# 2
# (4,)
# /home/tommy/anaconda3/envs/deep-learning-19/lib/python3.6/site-packages/gym/envs/registration.py:17: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# ## 1. Implement a DQN agent
# ## 1) Overview of implementation in the notebook
#
# The assignment is based on a method named by Deep Q-Network (DQN) [1,2]. You could find the details of DQN in the papers. The followings show briefly architecture of DQN and its training computation flow.
#
# - (Pink flow) Play an episode and save transition records of the episode into a replay memory.
# - (Green flow) Train DQN so that a loss function in the figure is minimized. The loss function is computed using main Q-network and Target Q-network. Target Q-network needs to be periodically updated by copying the main Q-network.
# - (Purple flow) Gradient can be autonomously computed by tensorflow engine, if you build a proper optimizer.
#
# ![](image/architecture.png)
#
# There are major 4 components, each of which needs to be implemented in this notebook. The Agent class must have an instance(s) of each class (Environment, DQN, ReplayMemory).
# - Environment
# - DQN
# - ReplayMemory
# - Agent
#
# ![](image/components.png)

# %% [markdown]
# ## 2) Design classes
#
# In the code cells, there are only names of functions which are used in TA's implementation and their brief explanations. <font color='green'>...</font> means that the functions need more arguments and <font color='green'>pass</font> means that you need to write more codes. The functions may be helpful when you do not know how to start the assignment. Of course, you could change the functions such as deleting/adding functions or extending/reducing roles of the classes, <font color='red'> just keeping the existence of the classes</font>.
#
# ### Environment class

# %%
EXPERIENCE_REPLAY_BATCH = 64
EXPERIENCE_BUFFER_SIZE = 100000
START_EPSILON = 0.99
END_EPSILON = 0.1
EPSILON_STEP_LIMIT = 100
LEARNING_RATE = 0.0025
DISCOUNT_FACTORE = 0.99
ALPHA = 1
class Environment(object):
    def __init__(self,env_name):
        self.env = gym.make(env_name)
        
    def step(self,action):
        next_state, reward, done, info = self.env.step(action)
        return next_state, reward, done, info

    def reset(self):
        return self.env.reset()

    def render(self):
        self.env.render()

# %% [markdown]
# ### ReplayMemory class

# %%
from collections import deque
import random

class ReplayMemory(object):
    def __init__(self):
        self.experience = []
        self.visited = {}

    def add(self, state, next_state, action, reward, is_done):
        state = np.array(state, dtype=np.float64)
        next_state = np.array(next_state, dtype=np.float64)
        experience = (state, next_state, action, reward, is_done)
        if len(self.experience) > EXPERIENCE_BUFFER_SIZE:
            self.experience = self.experience[1:]
        self.experience.append(experience)

    def recall(self):
        experience_size = len(self.experience)
        _EXPERIENCE_REPLAY_BATCH = EXPERIENCE_REPLAY_BATCH
        if experience_size < EXPERIENCE_REPLAY_BATCH:
            _EXPERIENCE_REPLAY_BATCH = experience_size

        indexes = np.random.randint(
            experience_size, size=_EXPERIENCE_REPLAY_BATCH)
        experiences = []
        for index in indexes:
            experiences.append(self.experience[index])

        return experiences

# %% [markdown]
# ### DQN class

# %%
class DQN(object):
    def __init__(self, input_size, output_size,sess_main):
        self.count = 0

        x = tf.placeholder(tf.float64, [None, input_size], name='x')
        y = tf.placeholder(tf.float64, [None, output_size], name='y')

        w1 = tf.Variable(tf.random_normal(
            [input_size, 64], dtype=tf.float64), name='w1')
        b1 = tf.Variable(tf.random_normal([64], dtype=tf.float64), name='b1')
        tf.summary.histogram('w1', w1)

        w2 = tf.Variable(tf.random_normal(
            [64, output_size], dtype=tf.float64), name='w2')
        b2 = tf.Variable(tf.random_normal(
            [output_size], dtype=tf.float64), name='b2')
        tf.summary.histogram('w2', w2)

        h1 = tf.add(tf.matmul(x, w1), b1, name='h1')
        relu_h1 = tf.nn.tanh(h1, name='relu_h1')
        tf.summary.histogram('relu_h1', relu_h1)

        self.model = tf.add(tf.matmul(relu_h1, w2), b2, name='model')
        tf.summary.histogram('model', self.model)

        self.error = tf.reduce_mean(tf.square(self.model - y), name='error')
        tf.summary.scalar('error', self.error)

        self.optimzer = tf.train.RMSPropOptimizer(
            LEARNING_RATE, name='Optimizer').minimize(self.error)
        self.step = 0
        self.sess = sess_main
        self.init = tf.global_variables_initializer()
        self.sess.run(self.init)
        self.merged = tf.summary.merge_all()
        self.summary_writter = tf.summary.FileWriter(
            "/tmp/cart_pole", self.sess.graph)
        
    def get_action(self, state):
        state = np.array(state, dtype=np.float64)
        output = self.sess.run([self.model], feed_dict={
            'x:0': state
        })
        return output[0][0]

    def train(self, states, actions):
        states = np.array(states, dtype=np.float64)
        actions = np.array(actions, dtype=np.float64)
        summary, _, error = self.sess.run([self.merged, self.optimzer, self.error], feed_dict={
            'x:0': states,
            'y:0': actions
        })
        self.summary_writter.add_summary(summary, self.count)
        self.count += 1

        return error

    def get_action_multiple(self, states):
        states = np.array(states, dtype=np.float64)
        output = self.sess.run([self.model], feed_dict={
            'x:0': states
        })

        return output[0]
        
    def close(self):
        self.sess.close()

# %% [markdown]
# ### Agent class

# %%
tf.reset_default_graph()
class Agent(object):
    def __init__(self,total_episodes, sess22):
        #
        self.sess = sess22
        env_name = "CartPole-v0"
        self.env = Environment(env_name)
        self.total_episodes = total_episodes
        self.epsilons = np.linspace(START_EPSILON, END_EPSILON)
        self.epsilons_index = 0
        self.epsilon = START_EPSILON
        self.total_actions = 0
        self.total_greedy_actions = 0
        self.model = DQN(4, 2,self.sess)
        self.memory = ReplayMemory()
        self.step = 0
        self.avg = []
        self.saver = tf.train.Saver()
    @staticmethod
    def is_greddy(epsilon):
        return np.random.choice([0, 1], 1, p=[epsilon, 1 - epsilon])[0]

    def update_epsilon(self):
        index = int(self.total_actions / EPSILON_STEP_LIMIT)
        if index > len(self.epsilons - 1):
            index = len(self.epsilons) - 1

        self.epsilons_index = index

    def take_action(self, state):

        self.total_actions += 1
        q_values = self.model.get_action(state.reshape(1, 4))
        is_greedy = Agent.is_greddy(self.epsilon)
        msg = ''
        if is_greedy:
            action = np.argmax(q_values)
        else:
            action = np.random.choice([0, 1], 1)[0]
            msg = 'explorer'

        self.epsilon = END_EPSILON + \
            (START_EPSILON - END_EPSILON) * \
            math.exp(-0.001 * self.total_actions)
        return action

    def observe_results(self, state, next_state, action, reward, is_done):
    
        self.memory.add(state, next_state, action, reward, is_done)
        self.update()

    def close(self):
        return self.model.close()

    def update(self):
        experiences = self.memory.recall()
        current_states = None
        next_states = None
        for experience in experiences:
            current_state, next_state, action, reward, is_done = experience
            current_state = np.array(current_state).reshape(1, 4)
            next_state = np.array(next_state).reshape(1, 4)
            if current_states is None:
                current_states = current_state
                next_states = next_state
            else:
                current_states = np.vstack((current_states, current_state))
                next_states = np.vstack((next_states, next_state))

        current_state_q_values = self.model.get_action_multiple(current_states)
        next_state_q_values = self.model.get_action_multiple(next_states)

        x = None
        y = None
        for i in range(len(experiences)):
            current_state, next_state, action, reward, is_done = experiences[i]
            current_state_q_value = np.array(
                current_state_q_values[i], dtype=np.float64)
            next_state_q_value = np.array(
                next_state_q_values[i], dtype=np.float64)
            if is_done:
                reward = -10
                next_state_q_value = [0.0, 0.0]

            current_state_q_value[action] = ALPHA * \
                (reward + DISCOUNT_FACTORE * np.amax(next_state_q_value))

            current_state = np.array(current_state).reshape(1, 4)
            current_state_q_value = np.array(
                current_state_q_value).reshape(1, 2)

            if x is None:
                x = current_state
                y = current_state_q_value
            else:
                x = np.vstack((x, current_state))
                y = np.vstack((y, current_state_q_value))
                
        self.model.train(x, y)

    def add_rewards(self, total_rewards):
        self.avg.append(total_rewards)
        l = len(self.avg)
        if l < 100:
            return False
        _avg = float(sum(self.avg[l - 100: l])) / max(len(self.avg[l - 100: l]), 1)
        print ('avg rewards: %s' % str(_avg))
        if _avg > 201:
            return True
        return False
    
    
    def play(self):
        episodes = 0
        total_reward = 0
        while episodes < self.total_episodes:
            print ('running episode: %s' % str(episodes + 1))
            state = self.env.reset()
            is_done = False
            total_reward = 0
            while not is_done:
                self.env.render()
                action = self.take_action(state)
                next_state, reward, is_done, info = self.env.step(action)
                self.step += 1
                total_reward += reward
                self.observe_results(
                    state, next_state, action, reward, is_done)
                state = next_state

            print ('rewards: %s, step: %s' % (str(total_reward), str(self.step)))
            if self.add_rewards(total_reward):
                print ('done with episods %s and steps: %s' % (str(episodes), str(self.step)))
                return
            episodes += 1
        return total_reward
    
    def save(self):
        checkpoint_dir = 'cartpole'
        if not os.path.exists(checkpoint_dir):
            os.mkdir(checkpoint_dir)
        self.saver.save(self.sess, os.path.join(checkpoint_dir, 'trained_agent'))
        
    def load(self):
        checkpoint_dir = 'cartpole'
        self.saver.restore(self.sess, os.path.join(checkpoint_dir, 'trained_agent'))
        
    def _plot(self):
        plt.plot(self.avg)
        plt.ylabel('Rewards')
        plt.xlabel('Episodes')
        plt.savefig('rewards.png')
        plt.show()

# %% [markdown]
# ## 2. Train your agent
#
# Now, you train an agent to play CartPole-v0. Options class is the collection of hyper-parameters that you can choice. Usage of Options class is not mandatory.<br>
# The maximum value of total reward which can be aquired from one episode is 200.
# <font color='red'>**You should show learning status such as the number of observed states and mean/max/min of rewards frequently (for instance, every 100 states).**</font>

# %%
tf.reset_default_graph()
import argparse
import easydict
parser = argparse.ArgumentParser(description="CartPole")
parser.add_argument('--env-name', default='CartPole-v0', type=str,
                    help="Environment")
parser.add_argument('--total_episodes', default=200, type=float,
                    help='1epsilons')

config = tf.ConfigProto()
with tf.Session(config=config) as sess:
    myAgent = Agent(200, sess) 
    myAgent.play()
    myAgent.save()
# Out:
# [2019-12-04 17:37:24,206] Making new env: CartPole-v0
# WARNING:tensorflow:From /home/tommy/anaconda3/envs/deep-learning-19/lib/python3.6/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [2019-12-04 17:37:24,261] From /home/tommy/anaconda3/envs/deep-learning-19/lib/python3.6/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# running episode: 1
# rewards: 34.0, step: 34
# running episode: 2
# rewards: 12.0, step: 46
# running episode: 3
# rewards: 9.0, step: 55
# running episode: 4
# rewards: 11.0, step: 66
# running episode: 5
# rewards: 11.0, step: 77
# running episode: 6
# rewards: 20.0, step: 97
# running episode: 7
# rewards: 15.0, step: 112
# running episode: 8
# rewards: 18.0, step: 130
# running episode: 9
# rewards: 26.0, step: 156
# running episode: 10
# rewards: 16.0, step: 172
# running episode: 11
# rewards: 87.0, step: 259
# running episode: 12
# rewards: 20.0, step: 279
# running episode: 13
# rewards: 12.0, step: 291
# running episode: 14
# rewards: 28.0, step: 319
# running episode: 15
# rewards: 16.0, step: 335
# running episode: 16
# rewards: 30.0, step: 365
# running episode: 17
# rewards: 49.0, step: 414
# running episode: 18
# rewards: 22.0, step: 436
# running episode: 19
# rewards: 48.0, step: 484
# running episode: 20
# rewards: 113.0, step: 597
# running episode: 21
# rewards: 49.0, step: 646
# running episode: 22
# rewards: 37.0, step: 683
# running episode: 23
# rewards: 69.0, step: 752
# running episode: 24
# rewards: 30.0, step: 782
# running episode: 25
# rewards: 68.0, step: 850
# running episode: 26
# rewards: 27.0, step: 877
# running episode: 27
# rewards: 100.0, step: 977
# running episode: 28
# rewards: 24.0, step: 1001
# running episode: 29
# rewards: 59.0, step: 1060
# running episode: 30
# rewards: 32.0, step: 1092
# running episode: 31
# rewards: 161.0, step: 1253
# running episode: 32
# rewards: 54.0, step: 1307
# running episode: 33
# rewards: 151.0, step: 1458
# running episode: 34
# rewards: 200.0, step: 1658
# running episode: 35
# rewards: 78.0, step: 1736
# running episode: 36
# rewards: 93.0, step: 1829
# running episode: 37
# rewards: 106.0, step: 1935
# running episode: 38
# rewards: 200.0, step: 2135
# running episode: 39
# rewards: 172.0, step: 2307
# running episode: 40
# rewards: 200.0, step: 2507
# running episode: 41
# rewards: 200.0, step: 2707
# running episode: 42
# rewards: 200.0, step: 2907
# running episode: 43
# rewards: 200.0, step: 3107
# running episode: 44
# rewards: 200.0, step: 3307
# running episode: 45
# rewards: 200.0, step: 3507
# running episode: 46
# rewards: 200.0, step: 3707
# running episode: 47
# rewards: 200.0, step: 3907
# running episode: 48
# rewards: 200.0, step: 4107
# running episode: 49
# rewards: 200.0, step: 4307
# running episode: 50
# rewards: 200.0, step: 4507
# running episode: 51
# rewards: 200.0, step: 4707
# running episode: 52
# rewards: 200.0, step: 4907
# running episode: 53
# rewards: 200.0, step: 5107
# running episode: 54
# rewards: 200.0, step: 5307
# running episode: 55
# rewards: 200.0, step: 5507
# running episode: 56
# rewards: 200.0, step: 5707
# running episode: 57
# rewards: 200.0, step: 5907
# running episode: 58
# rewards: 200.0, step: 6107
# running episode: 59
# rewards: 200.0, step: 6307
# running episode: 60
# rewards: 200.0, step: 6507
# running episode: 61
# rewards: 200.0, step: 6707
# running episode: 62
# rewards: 200.0, step: 6907
# running episode: 63
# rewards: 200.0, step: 7107
# running episode: 64
# rewards: 200.0, step: 7307
# running episode: 65
# rewards: 200.0, step: 7507
# running episode: 66
# rewards: 200.0, step: 7707
# running episode: 67
# rewards: 200.0, step: 7907
# running episode: 68
# rewards: 200.0, step: 8107
# running episode: 69
# rewards: 200.0, step: 8307
# running episode: 70
# rewards: 200.0, step: 8507
# running episode: 71
# rewards: 200.0, step: 8707
# running episode: 72
# rewards: 200.0, step: 8907
# running episode: 73
# rewards: 200.0, step: 9107
# running episode: 74
# rewards: 200.0, step: 9307
# running episode: 75
# rewards: 200.0, step: 9507
# running episode: 76
# rewards: 200.0, step: 9707
# running episode: 77
# rewards: 200.0, step: 9907
# running episode: 78
# rewards: 200.0, step: 10107
# running episode: 79
# rewards: 200.0, step: 10307
# running episode: 80
# rewards: 194.0, step: 10501
# running episode: 81
# rewards: 200.0, step: 10701
# running episode: 82
# rewards: 200.0, step: 10901
# running episode: 83
# rewards: 200.0, step: 11101
# running episode: 84
# rewards: 200.0, step: 11301
# running episode: 85
# rewards: 200.0, step: 11501
# running episode: 86
# rewards: 200.0, step: 11701
# running episode: 87
# rewards: 200.0, step: 11901
# running episode: 88
# rewards: 192.0, step: 12093
# running episode: 89
# rewards: 200.0, step: 12293
# running episode: 90
# rewards: 200.0, step: 12493
# running episode: 91
# rewards: 200.0, step: 12693
# running episode: 92
# rewards: 153.0, step: 12846
# running episode: 93
# rewards: 200.0, step: 13046
# running episode: 94
# rewards: 200.0, step: 13246
# running episode: 95
# rewards: 200.0, step: 13446
# running episode: 96
# rewards: 190.0, step: 13636
# running episode: 97
# rewards: 200.0, step: 13836
# running episode: 98
# rewards: 200.0, step: 14036
# running episode: 99
# rewards: 200.0, step: 14236
# running episode: 100
# rewards: 200.0, step: 14436
# avg rewards: 144.36
# running episode: 101
# rewards: 200.0, step: 14636
# avg rewards: 146.02
# running episode: 102
# rewards: 200.0, step: 14836
# avg rewards: 147.9
# running episode: 103
# rewards: 200.0, step: 15036
# avg rewards: 149.81
# running episode: 104
# rewards: 200.0, step: 15236
# avg rewards: 151.7
# running episode: 105
# rewards: 200.0, step: 15436
# avg rewards: 153.59
# running episode: 106
# rewards: 200.0, step: 15636
# avg rewards: 155.39
# running episode: 107
# rewards: 200.0, step: 15836
# avg rewards: 157.24
# running episode: 108
# rewards: 200.0, step: 16036
# avg rewards: 159.06
# running episode: 109
# rewards: 200.0, step: 16236
# avg rewards: 160.8
# running episode: 110
# rewards: 200.0, step: 16436
# avg rewards: 162.64
# running episode: 111
# rewards: 200.0, step: 16636
# avg rewards: 163.77
# running episode: 112
# rewards: 200.0, step: 16836
# avg rewards: 165.57
# running episode: 113
# rewards: 200.0, step: 17036
# avg rewards: 167.45
# running episode: 114
# rewards: 200.0, step: 17236
# avg rewards: 169.17
# running episode: 115
# rewards: 200.0, step: 17436
# avg rewards: 171.01
# running episode: 116
# rewards: 200.0, step: 17636
# avg rewards: 172.71
# running episode: 117
# rewards: 200.0, step: 17836
# avg rewards: 174.22
# running episode: 118
# rewards: 199.0, step: 18035
# avg rewards: 175.99
# running episode: 119
# rewards: 200.0, step: 18235
# avg rewards: 177.51
# running episode: 120
# rewards: 200.0, step: 18435
# avg rewards: 178.38
# running episode: 121
# rewards: 200.0, step: 18635
# avg rewards: 179.89
# running episode: 122
# rewards: 200.0, step: 18835
# avg rewards: 181.52
# running episode: 123
# rewards: 200.0, step: 19035
# avg rewards: 182.83
# running episode: 124
# rewards: 200.0, step: 19235
# avg rewards: 184.53
# running episode: 125
# rewards: 200.0, step: 19435
# avg rewards: 185.85
# running episode: 126
# rewards: 200.0, step: 19635
# avg rewards: 187.58
# running episode: 127
# rewards: 200.0, step: 19835
# avg rewards: 188.58
# running episode: 128
# rewards: 200.0, step: 20035
# avg rewards: 190.34
# running episode: 129
# rewards: 200.0, step: 20235
# avg rewards: 191.75
# running episode: 130
# rewards: 200.0, step: 20435
# avg rewards: 193.43
# running episode: 131
# rewards: 200.0, step: 20635
# avg rewards: 193.82
# running episode: 132
# rewards: 200.0, step: 20835
# avg rewards: 195.28
# running episode: 133
# rewards: 200.0, step: 21035
# avg rewards: 195.77
# running episode: 134
# rewards: 200.0, step: 21235
# avg rewards: 195.77
# running episode: 135
# rewards: 200.0, step: 21435
# avg rewards: 196.99
# running episode: 136
# rewards: 200.0, step: 21635
# avg rewards: 198.06
# running episode: 137
# rewards: 200.0, step: 21835
# avg rewards: 199.0
# running episode: 138
# rewards: 200.0, step: 22035
# avg rewards: 199.0
# running episode: 139
# rewards: 200.0, step: 22235
# avg rewards: 199.28
# running episode: 140
# rewards: 200.0, step: 22435
# avg rewards: 199.28
# running episode: 141
# rewards: 200.0, step: 22635
# avg rewards: 199.28
# running episode: 142
# rewards: 200.0, step: 22835
# avg rewards: 199.28
# running episode: 143
# rewards: 200.0, step: 23035
# avg rewards: 199.28
# running episode: 144
# rewards: 200.0, step: 23235
# avg rewards: 199.28
# running episode: 145
# rewards: 200.0, step: 23435
# avg rewards: 199.28
# running episode: 146
# rewards: 200.0, step: 23635
# avg rewards: 199.28
# running episode: 147
# rewards: 200.0, step: 23835
# avg rewards: 199.28
# running episode: 148
# rewards: 200.0, step: 24035
# avg rewards: 199.28
# running episode: 149
# rewards: 200.0, step: 24235
# avg rewards: 199.28
# running episode: 150
# rewards: 200.0, step: 24435
# avg rewards: 199.28
# running episode: 151
# rewards: 200.0, step: 24635
# avg rewards: 199.28
# running episode: 152
# rewards: 200.0, step: 24835
# avg rewards: 199.28
# running episode: 153
# rewards: 200.0, step: 25035
# avg rewards: 199.28
# running episode: 154
# rewards: 200.0, step: 25235
# avg rewards: 199.28
# running episode: 155
# rewards: 200.0, step: 25435
# avg rewards: 199.28
# running episode: 156
# rewards: 200.0, step: 25635
# avg rewards: 199.28
# running episode: 157
# rewards: 200.0, step: 25835
# avg rewards: 199.28
# running episode: 158
# rewards: 200.0, step: 26035
# avg rewards: 199.28
# running episode: 159
# rewards: 200.0, step: 26235
# avg rewards: 199.28
# running episode: 160
# rewards: 200.0, step: 26435
# avg rewards: 199.28
# running episode: 161
# rewards: 200.0, step: 26635
# avg rewards: 199.28
# running episode: 162
# rewards: 200.0, step: 26835
# avg rewards: 199.28
# running episode: 163
# rewards: 200.0, step: 27035
# avg rewards: 199.28
# running episode: 164
# rewards: 200.0, step: 27235
# avg rewards: 199.28
# running episode: 165
# rewards: 200.0, step: 27435
# avg rewards: 199.28
# running episode: 166
# rewards: 200.0, step: 27635
# avg rewards: 199.28
# running episode: 167
# rewards: 200.0, step: 27835
# avg rewards: 199.28
# running episode: 168
# rewards: 200.0, step: 28035
# avg rewards: 199.28
# running episode: 169
# rewards: 200.0, step: 28235
# avg rewards: 199.28
# running episode: 170
# rewards: 200.0, step: 28435
# avg rewards: 199.28
# running episode: 171
# rewards: 200.0, step: 28635
# avg rewards: 199.28
# running episode: 172
# rewards: 200.0, step: 28835
# avg rewards: 199.28
# running episode: 173
# rewards: 200.0, step: 29035
# avg rewards: 199.28
# running episode: 174
# rewards: 200.0, step: 29235
# avg rewards: 199.28
# running episode: 175
# rewards: 200.0, step: 29435
# avg rewards: 199.28
# running episode: 176
# rewards: 200.0, step: 29635
# avg rewards: 199.28
# running episode: 177
# rewards: 200.0, step: 29835
# avg rewards: 199.28
# running episode: 178
# rewards: 200.0, step: 30035
# avg rewards: 199.28
# running episode: 179
# rewards: 200.0, step: 30235
# avg rewards: 199.28
# running episode: 180
# rewards: 200.0, step: 30435
# avg rewards: 199.34
# running episode: 181
# rewards: 200.0, step: 30635
# avg rewards: 199.34
# running episode: 182
# rewards: 180.0, step: 30815
# avg rewards: 199.14
# running episode: 183
# rewards: 180.0, step: 30995
# avg rewards: 198.94
# running episode: 184
# rewards: 200.0, step: 31195
# avg rewards: 198.94
# running episode: 185
# rewards: 200.0, step: 31395
# avg rewards: 198.94
# running episode: 186
# rewards: 200.0, step: 31595
# avg rewards: 198.94
# running episode: 187
# rewards: 200.0, step: 31795
# avg rewards: 198.94
# running episode: 188
# rewards: 200.0, step: 31995
# avg rewards: 199.02
# running episode: 189
# rewards: 200.0, step: 32195
# avg rewards: 199.02
# running episode: 190
# rewards: 200.0, step: 32395
# avg rewards: 199.02
# running episode: 191
# rewards: 200.0, step: 32595
# avg rewards: 199.02
# running episode: 192
# rewards: 200.0, step: 32795
# avg rewards: 199.49
# running episode: 193
# rewards: 200.0, step: 32995
# avg rewards: 199.49
# running episode: 194
# rewards: 200.0, step: 33195
# avg rewards: 199.49
# running episode: 195
# rewards: 200.0, step: 33395
# avg rewards: 199.49
# running episode: 196
# rewards: 200.0, step: 33595
# avg rewards: 199.59
# running episode: 197
# rewards: 200.0, step: 33795
# avg rewards: 199.59
# running episode: 198
# rewards: 200.0, step: 33995
# avg rewards: 199.59
# running episode: 199
# rewards: 200.0, step: 34195
# avg rewards: 199.59
# running episode: 200
# rewards: 200.0, step: 34395
# avg rewards: 199.59

# %% [markdown]
# ## <a name="play"></a> 3. Test the trained agent ( 50 points )
#
# Now, we test your agent and calculate an average reward of 20 episodes.
# - 0 <= average reward < 50 : you can get 0 points
# - 50 <= average reward < 100 : you can get 10 points
# - 100 <= average reward < 190 : you can get 35 points
# - 190 <= average reward <= 200 : you can get 50 points

# %%
tf.reset_default_graph()
config = tf.ConfigProto()
with tf.Session(config=config) as sess:
    myAgent = Agent(20, sess) 
    myAgent.load()
    rewards = []
    for i in range(20):
        r = myAgent.play()
        rewards.append(r)
    mean = np.mean(rewards,dtype=np.float64)
    print(rewards)
    print("Average reward of 20 episodes is: ")
    print(mean)
# Out:
# [2019-12-04 18:13:00,177] Making new env: CartPole-v0
# WARNING:tensorflow:From /home/tommy/anaconda3/envs/deep-learning-19/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# [2019-12-04 18:13:00,333] From /home/tommy/anaconda3/envs/deep-learning-19/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from cartpole/trained_agent
# [2019-12-04 18:13:00,335] Restoring parameters from cartpole/trained_agent
# running episode: 1
# rewards: 37.0, step: 37
# running episode: 2
# rewards: 23.0, step: 60
# running episode: 3
# rewards: 12.0, step: 72
# running episode: 4
# rewards: 13.0, step: 85
# running episode: 5
# rewards: 14.0, step: 99
# running episode: 6
# rewards: 19.0, step: 118
# running episode: 7
# rewards: 14.0, step: 132
# running episode: 8
# rewards: 39.0, step: 171
# running episode: 9
# rewards: 25.0, step: 196
# running episode: 10
# rewards: 30.0, step: 226
# running episode: 11
# rewards: 175.0, step: 401
# running episode: 12
# rewards: 51.0, step: 452
# running episode: 13
# rewards: 40.0, step: 492
# running episode: 14
# rewards: 132.0, step: 624
# running episode: 15
# rewards: 20.0, step: 644
# running episode: 16
# rewards: 53.0, step: 697
# running episode: 17
# rewards: 116.0, step: 813
# running episode: 18
# rewards: 149.0, step: 962
# running episode: 19
# rewards: 200.0, step: 1162
# running episode: 20
# rewards: 182.0, step: 1344
# running episode: 1
# rewards: 200.0, step: 1544
# running episode: 2
# rewards: 159.0, step: 1703
# running episode: 3
# rewards: 194.0, step: 1897
# running episode: 4
# rewards: 200.0, step: 2097
# running episode: 5
# rewards: 135.0, step: 2232
# running episode: 6
# rewards: 200.0, step: 2432
# running episode: 7
# rewards: 200.0, step: 2632
# running episode: 8
# rewards: 165.0, step: 2797
# running episode: 9
# rewards: 200.0, step: 2997
# running episode: 10
# rewards: 196.0, step: 3193
# running episode: 11
# rewards: 200.0, step: 3393
# running episode: 12
# rewards: 196.0, step: 3589
# running episode: 13
# rewards: 200.0, step: 3789
# running episode: 14
# rewards: 200.0, step: 3989
# running episode: 15
# rewards: 199.0, step: 4188
# running episode: 16
# rewards: 200.0, step: 4388
# running episode: 17
# rewards: 200.0, step: 4588
# running episode: 18
# rewards: 200.0, step: 4788
# running episode: 19
# rewards: 200.0, step: 4988
# running episode: 20
# rewards: 200.0, step: 5188
# running episode: 1
# rewards: 200.0, step: 5388
# running episode: 2
# rewards: 190.0, step: 5578
# running episode: 3
# rewards: 200.0, step: 5778
# running episode: 4
# rewards: 200.0, step: 5978
# running episode: 5
# rewards: 199.0, step: 6177
# running episode: 6
# rewards: 200.0, step: 6377
# running episode: 7
# rewards: 200.0, step: 6577
# running episode: 8
# rewards: 200.0, step: 6777
# running episode: 9
# rewards: 200.0, step: 6977
# running episode: 10
# rewards: 200.0, step: 7177
# running episode: 11
# rewards: 200.0, step: 7377
# running episode: 12
# rewards: 200.0, step: 7577
# running episode: 13
# rewards: 200.0, step: 7777
# running episode: 14
# rewards: 200.0, step: 7977
# running episode: 15
# rewards: 200.0, step: 8177
# running episode: 16
# rewards: 200.0, step: 8377
# running episode: 17
# rewards: 200.0, step: 8577
# running episode: 18
# rewards: 200.0, step: 8777
# running episode: 19
# rewards: 200.0, step: 8977
# running episode: 20
# rewards: 200.0, step: 9177
# running episode: 1
# rewards: 200.0, step: 9377
# running episode: 2
# rewards: 200.0, step: 9577
# running episode: 3
# rewards: 200.0, step: 9777
# running episode: 4
# rewards: 200.0, step: 9977
# running episode: 5
# rewards: 200.0, step: 10177
# running episode: 6
# rewards: 200.0, step: 10377
# running episode: 7
# rewards: 200.0, step: 10577
# running episode: 8
# rewards: 199.0, step: 10776
# running episode: 9
# rewards: 200.0, step: 10976
# running episode: 10
# rewards: 200.0, step: 11176
# running episode: 11
# rewards: 200.0, step: 11376
# running episode: 12
# rewards: 200.0, step: 11576
# running episode: 13
# rewards: 200.0, step: 11776
# running episode: 14
# rewards: 200.0, step: 11976
# running episode: 15
# rewards: 200.0, step: 12176
# running episode: 16
# rewards: 200.0, step: 12376
# running episode: 17
# rewards: 200.0, step: 12576
# running episode: 18
# rewards: 200.0, step: 12776
# running episode: 19
# rewards: 200.0, step: 12976
# running episode: 20
# rewards: 200.0, step: 13176
# running episode: 1
# rewards: 200.0, step: 13376
# running episode: 2
# rewards: 200.0, step: 13576
# running episode: 3
# rewards: 200.0, step: 13776
# running episode: 4
# rewards: 200.0, step: 13976
# running episode: 5
# rewards: 200.0, step: 14176
# running episode: 6
# rewards: 200.0, step: 14376
# running episode: 7
# rewards: 200.0, step: 14576
# running episode: 8
# rewards: 200.0, step: 14776
# running episode: 9
# rewards: 200.0, step: 14976
# running episode: 10
# rewards: 200.0, step: 15176
# running episode: 11
# rewards: 200.0, step: 15376
# running episode: 12
# rewards: 199.0, step: 15575
# running episode: 13
# rewards: 200.0, step: 15775
# running episode: 14
# rewards: 200.0, step: 15975
# running episode: 15
# rewards: 187.0, step: 16162
# running episode: 16
# rewards: 168.0, step: 16330
# running episode: 17
# rewards: 200.0, step: 16530
# running episode: 18
# rewards: 182.0, step: 16712
# running episode: 19
# rewards: 200.0, step: 16912
# running episode: 20
# rewards: 200.0, step: 17112
# avg rewards: 171.12
# running episode: 1
# rewards: 200.0, step: 17312
# avg rewards: 172.75
# running episode: 2
# rewards: 200.0, step: 17512
# avg rewards: 174.52
# running episode: 3
# rewards: 200.0, step: 17712
# avg rewards: 176.4
# running episode: 4
# rewards: 200.0, step: 17912
# avg rewards: 178.27
# running episode: 5
# rewards: 200.0, step: 18112
# avg rewards: 180.13
# running episode: 6
# rewards: 198.0, step: 18310
# avg rewards: 181.92
# running episode: 7
# rewards: 200.0, step: 18510
# avg rewards: 183.78
# running episode: 8
# rewards: 200.0, step: 18710
# avg rewards: 185.39
# running episode: 9
# rewards: 200.0, step: 18910
# avg rewards: 187.14
# running episode: 10
# rewards: 200.0, step: 19110
# avg rewards: 188.84
# running episode: 11
# rewards: 200.0, step: 19310
# avg rewards: 189.09
# running episode: 12
# rewards: 200.0, step: 19510
# avg rewards: 190.58
# running episode: 13
# rewards: 200.0, step: 19710
# avg rewards: 192.18
# running episode: 14
# rewards: 200.0, step: 19910
# avg rewards: 192.86
# running episode: 15
# rewards: 200.0, step: 20110
# avg rewards: 194.66
# running episode: 16
# rewards: 200.0, step: 20310
# avg rewards: 196.13
# running episode: 17
# rewards: 200.0, step: 20510
# avg rewards: 196.97
# running episode: 18
# rewards: 200.0, step: 20710
# avg rewards: 197.48
# running episode: 19
# rewards: 200.0, step: 20910
# avg rewards: 197.48
# running episode: 20
# rewards: 200.0, step: 21110
# avg rewards: 197.66
# running episode: 1
# rewards: 200.0, step: 21310
# avg rewards: 197.66
# running episode: 2
# rewards: 200.0, step: 21510
# avg rewards: 198.07
# running episode: 3
# rewards: 200.0, step: 21710
# avg rewards: 198.13
# running episode: 4
# rewards: 200.0, step: 21910
# avg rewards: 198.13
# running episode: 5
# rewards: 200.0, step: 22110
# avg rewards: 198.78
# running episode: 6
# rewards: 200.0, step: 22310
# avg rewards: 198.78
# running episode: 7
# rewards: 200.0, step: 22510
# avg rewards: 198.78
# running episode: 8
# rewards: 193.0, step: 22703
# avg rewards: 199.06
# running episode: 9
# rewards: 200.0, step: 22903
# avg rewards: 199.06
# running episode: 10
# rewards: 200.0, step: 23103
# avg rewards: 199.1
# running episode: 11
# rewards: 200.0, step: 23303
# avg rewards: 199.1
# running episode: 12
# rewards: 200.0, step: 23503
# avg rewards: 199.14
# running episode: 13
# rewards: 200.0, step: 23703
# avg rewards: 199.14
# running episode: 14
# rewards: 200.0, step: 23903
# avg rewards: 199.14
# running episode: 15
# rewards: 200.0, step: 24103
# avg rewards: 199.15
# running episode: 16
# rewards: 200.0, step: 24303
# avg rewards: 199.15
# running episode: 17
# rewards: 200.0, step: 24503
# avg rewards: 199.15
# running episode: 18
# rewards: 200.0, step: 24703
# avg rewards: 199.15
# running episode: 19
# rewards: 200.0, step: 24903
# avg rewards: 199.15
# running episode: 20
# rewards: 200.0, step: 25103
# avg rewards: 199.15
# running episode: 1
# rewards: 200.0, step: 25303
# avg rewards: 199.15
# running episode: 2
# rewards: 200.0, step: 25503
# avg rewards: 199.25
# running episode: 3
# rewards: 200.0, step: 25703
# avg rewards: 199.25
# running episode: 4
# rewards: 200.0, step: 25903
# avg rewards: 199.25
# running episode: 5
# rewards: 200.0, step: 26103
# avg rewards: 199.26
# running episode: 6
# rewards: 200.0, step: 26303
# avg rewards: 199.26
# running episode: 7
# rewards: 200.0, step: 26503
# avg rewards: 199.26
# running episode: 8
# rewards: 200.0, step: 26703
# avg rewards: 199.26
# running episode: 9
# rewards: 200.0, step: 26903
# avg rewards: 199.26
# running episode: 10
# rewards: 200.0, step: 27103
# avg rewards: 199.26
# running episode: 11
# rewards: 200.0, step: 27303
# avg rewards: 199.26
# running episode: 12
# rewards: 200.0, step: 27503
# avg rewards: 199.26
# running episode: 13
# rewards: 200.0, step: 27703
# avg rewards: 199.26
# running episode: 14
# rewards: 200.0, step: 27903
# avg rewards: 199.26
# running episode: 15
# rewards: 200.0, step: 28103
# avg rewards: 199.26
# running episode: 16
# rewards: 200.0, step: 28303
# avg rewards: 199.26
# running episode: 17
# rewards: 200.0, step: 28503
# avg rewards: 199.26
# running episode: 18
# rewards: 200.0, step: 28703
# avg rewards: 199.26
# running episode: 19
# rewards: 200.0, step: 28903
# avg rewards: 199.26
# running episode: 20
# rewards: 200.0, step: 29103
# avg rewards: 199.26
# running episode: 1
# rewards: 200.0, step: 29303
# avg rewards: 199.26
# running episode: 2
# rewards: 200.0, step: 29503
# avg rewards: 199.26
# running episode: 3
# rewards: 200.0, step: 29703
# avg rewards: 199.26
# running episode: 4
# rewards: 200.0, step: 29903
# avg rewards: 199.26
# running episode: 5
# rewards: 200.0, step: 30103
# avg rewards: 199.26
# running episode: 6
# rewards: 200.0, step: 30303
# avg rewards: 199.26
# running episode: 7
# rewards: 183.0, step: 30486
# avg rewards: 199.09
# running episode: 8
# rewards: 200.0, step: 30686
# avg rewards: 199.1
# running episode: 9
# rewards: 193.0, step: 30879
# avg rewards: 199.03
# running episode: 10
# rewards: 200.0, step: 31079
# avg rewards: 199.03
# running episode: 11
# rewards: 200.0, step: 31279
# avg rewards: 199.03
# running episode: 12
# rewards: 165.0, step: 31444
# avg rewards: 198.68
# running episode: 13
# rewards: 200.0, step: 31644
# avg rewards: 198.68
# running episode: 14
# rewards: 200.0, step: 31844
# avg rewards: 198.68
# running episode: 15
# rewards: 200.0, step: 32044
# avg rewards: 198.68
# running episode: 16
# rewards: 200.0, step: 32244
# avg rewards: 198.68
# running episode: 17
# rewards: 162.0, step: 32406
# avg rewards: 198.3
# running episode: 18
# rewards: 164.0, step: 32570
# avg rewards: 197.94
# running episode: 19
# rewards: 200.0, step: 32770
# avg rewards: 197.94
# running episode: 20
# rewards: 200.0, step: 32970
# avg rewards: 197.94
# running episode: 1
# rewards: 200.0, step: 33170
# avg rewards: 197.94
# running episode: 2
# rewards: 200.0, step: 33370
# avg rewards: 197.94
# running episode: 3
# rewards: 200.0, step: 33570
# avg rewards: 197.94
# running episode: 4
# rewards: 200.0, step: 33770
# avg rewards: 197.94
# running episode: 5
# rewards: 200.0, step: 33970
# avg rewards: 197.94
# running episode: 6
# rewards: 200.0, step: 34170
# avg rewards: 197.94
# running episode: 7
# rewards: 200.0, step: 34370
# avg rewards: 197.94
# running episode: 8
# rewards: 200.0, step: 34570
# avg rewards: 197.94
# running episode: 9
# rewards: 200.0, step: 34770
# avg rewards: 197.94
# running episode: 10
# rewards: 200.0, step: 34970
# avg rewards: 197.94
# running episode: 11
# rewards: 200.0, step: 35170
# avg rewards: 197.94
# running episode: 12
# rewards: 200.0, step: 35370
# avg rewards: 197.95
# running episode: 13
# rewards: 200.0, step: 35570
# avg rewards: 197.95
# running episode: 14
# rewards: 200.0, step: 35770
# avg rewards: 197.95
# running episode: 15
# rewards: 200.0, step: 35970
# avg rewards: 198.08
# running episode: 16
# rewards: 200.0, step: 36170
# avg rewards: 198.4
# running episode: 17
# rewards: 200.0, step: 36370
# avg rewards: 198.4
# running episode: 18
# rewards: 200.0, step: 36570
# avg rewards: 198.58
# running episode: 19
# rewards: 200.0, step: 36770
# avg rewards: 198.58
# running episode: 20
# rewards: 200.0, step: 36970
# avg rewards: 198.58
# running episode: 1
# rewards: 200.0, step: 37170
# avg rewards: 198.58
# running episode: 2
# rewards: 200.0, step: 37370
# avg rewards: 198.58
# running episode: 3
# rewards: 200.0, step: 37570
# avg rewards: 198.58
# running episode: 4
# rewards: 200.0, step: 37770
# avg rewards: 198.58
# running episode: 5
# rewards: 200.0, step: 37970
# avg rewards: 198.58
# running episode: 6
# rewards: 200.0, step: 38170
# avg rewards: 198.6
# running episode: 7
# rewards: 200.0, step: 38370
# avg rewards: 198.6
# running episode: 8
# rewards: 200.0, step: 38570
# avg rewards: 198.6
# running episode: 9
# rewards: 200.0, step: 38770
# avg rewards: 198.6
# running episode: 10
# rewards: 200.0, step: 38970
# avg rewards: 198.6
# running episode: 11
# rewards: 200.0, step: 39170
# avg rewards: 198.6
# running episode: 12
# rewards: 200.0, step: 39370
# avg rewards: 198.6
# running episode: 13
# rewards: 200.0, step: 39570
# avg rewards: 198.6
# running episode: 14
# rewards: 200.0, step: 39770
# avg rewards: 198.6
# running episode: 15
# rewards: 200.0, step: 39970
# avg rewards: 198.6
# running episode: 16
# rewards: 200.0, step: 40170
# avg rewards: 198.6
# running episode: 17
# rewards: 200.0, step: 40370
# avg rewards: 198.6
# running episode: 18
# rewards: 200.0, step: 40570
# avg rewards: 198.6
# running episode: 19
# rewards: 200.0, step: 40770
# avg rewards: 198.6
# running episode: 20
# rewards: 200.0, step: 40970
# avg rewards: 198.6
# running episode: 1
# rewards: 200.0, step: 41170
# avg rewards: 198.6
# running episode: 2
# rewards: 200.0, step: 41370
# avg rewards: 198.6
# running episode: 3
# rewards: 200.0, step: 41570
# avg rewards: 198.6
# running episode: 4
# rewards: 200.0, step: 41770
# avg rewards: 198.6
# running episode: 5
# rewards: 200.0, step: 41970
# avg rewards: 198.6
# running episode: 6
# rewards: 200.0, step: 42170
# avg rewards: 198.6
# running episode: 7
# rewards: 200.0, step: 42370
# avg rewards: 198.6
# running episode: 8
# rewards: 200.0, step: 42570
# avg rewards: 198.67
# running episode: 9
# rewards: 200.0, step: 42770
# avg rewards: 198.67
# running episode: 10
# rewards: 200.0, step: 42970
# avg rewards: 198.67
# running episode: 11
# rewards: 200.0, step: 43170
# avg rewards: 198.67
# running episode: 12
# rewards: 200.0, step: 43370
# avg rewards: 198.67
# running episode: 13
# rewards: 200.0, step: 43570
# avg rewards: 198.67
# running episode: 14
# rewards: 200.0, step: 43770
# avg rewards: 198.67
# running episode: 15
# rewards: 200.0, step: 43970
# avg rewards: 198.67
# running episode: 16
# rewards: 200.0, step: 44170
# avg rewards: 198.67
# running episode: 17
# rewards: 135.0, step: 44305
# avg rewards: 198.02
# running episode: 18
# rewards: 200.0, step: 44505
# avg rewards: 198.02
# running episode: 19
# rewards: 147.0, step: 44652
# avg rewards: 197.49
# running episode: 20
# rewards: 200.0, step: 44852
# avg rewards: 197.49
# running episode: 1
# rewards: 200.0, step: 45052
# avg rewards: 197.49
# running episode: 2
# rewards: 200.0, step: 45252
# avg rewards: 197.49
# running episode: 3
# rewards: 200.0, step: 45452
# avg rewards: 197.49
# running episode: 4
# rewards: 200.0, step: 45652
# avg rewards: 197.49
# running episode: 5
# rewards: 200.0, step: 45852
# avg rewards: 197.49
# running episode: 6
# rewards: 200.0, step: 46052
# avg rewards: 197.49
# running episode: 7
# rewards: 200.0, step: 46252
# avg rewards: 197.49
# running episode: 8
# rewards: 200.0, step: 46452
# avg rewards: 197.49
# running episode: 9
# rewards: 200.0, step: 46652
# avg rewards: 197.49
# running episode: 10
# rewards: 200.0, step: 46852
# avg rewards: 197.49
# running episode: 11
# rewards: 200.0, step: 47052
# avg rewards: 197.49
# running episode: 12
# rewards: 200.0, step: 47252
# avg rewards: 197.49
# running episode: 13
# rewards: 200.0, step: 47452
# avg rewards: 197.49
# running episode: 14
# rewards: 200.0, step: 47652
# avg rewards: 197.49
# running episode: 15
# rewards: 200.0, step: 47852
# avg rewards: 197.49
# running episode: 16
# rewards: 200.0, step: 48052
# avg rewards: 197.49
# running episode: 17
# rewards: 200.0, step: 48252
# avg rewards: 197.49
# running episode: 18
# rewards: 200.0, step: 48452
# avg rewards: 197.49
# running episode: 19
# rewards: 200.0, step: 48652
# avg rewards: 197.49
# running episode: 20
# rewards: 200.0, step: 48852
# avg rewards: 197.49
# running episode: 1
# rewards: 200.0, step: 49052
# avg rewards: 197.49
# running episode: 2
# rewards: 200.0, step: 49252
# avg rewards: 197.49
# running episode: 3
# rewards: 200.0, step: 49452
# avg rewards: 197.49
# running episode: 4
# rewards: 200.0, step: 49652
# avg rewards: 197.49
# running episode: 5
# rewards: 200.0, step: 49852
# avg rewards: 197.49
# running episode: 6
# rewards: 200.0, step: 50052
# avg rewards: 197.49
# running episode: 7
# rewards: 200.0, step: 50252
# avg rewards: 197.66
# running episode: 8
# rewards: 200.0, step: 50452
# avg rewards: 197.66
# running episode: 9
# rewards: 200.0, step: 50652
# avg rewards: 197.73
# running episode: 10
# rewards: 200.0, step: 50852
# avg rewards: 197.73
# running episode: 11
# rewards: 200.0, step: 51052
# avg rewards: 197.73
# running episode: 12
# rewards: 200.0, step: 51252
# avg rewards: 198.08
# running episode: 13
# rewards: 200.0, step: 51452
# avg rewards: 198.08
# running episode: 14
# rewards: 200.0, step: 51652
# avg rewards: 198.08
# running episode: 15
# rewards: 200.0, step: 51852
# avg rewards: 198.08
# running episode: 16
# rewards: 200.0, step: 52052
# avg rewards: 198.08
# running episode: 17
# rewards: 200.0, step: 52252
# avg rewards: 198.46
# running episode: 18
# rewards: 200.0, step: 52452
# avg rewards: 198.82
# running episode: 19
# rewards: 200.0, step: 52652
# avg rewards: 198.82
# running episode: 20
# rewards: 200.0, step: 52852
# avg rewards: 198.82
# running episode: 1
# rewards: 200.0, step: 53052
# avg rewards: 198.82
# running episode: 2
# rewards: 200.0, step: 53252
# avg rewards: 198.82
# running episode: 3
# rewards: 200.0, step: 53452
# avg rewards: 198.82
# running episode: 4
# rewards: 165.0, step: 53617
# avg rewards: 198.47
# running episode: 5
# rewards: 200.0, step: 53817
# avg rewards: 198.47
# running episode: 6
# rewards: 200.0, step: 54017
# avg rewards: 198.47
# running episode: 7
# rewards: 200.0, step: 54217
# avg rewards: 198.47
# running episode: 8
# rewards: 200.0, step: 54417
# avg rewards: 198.47
# running episode: 9
# rewards: 182.0, step: 54599
# avg rewards: 198.29
# running episode: 10
# rewards: 200.0, step: 54799
# avg rewards: 198.29
# running episode: 11
# rewards: 183.0, step: 54982
# avg rewards: 198.12
# running episode: 12
# rewards: 200.0, step: 55182
# avg rewards: 198.12
# running episode: 13
# rewards: 200.0, step: 55382
# avg rewards: 198.12
# running episode: 14
# rewards: 186.0, step: 55568
# avg rewards: 197.98
# running episode: 15
# rewards: 200.0, step: 55768
# avg rewards: 197.98
# running episode: 16
# rewards: 200.0, step: 55968
# avg rewards: 197.98
# running episode: 17
# rewards: 200.0, step: 56168
# avg rewards: 197.98
# running episode: 18
# rewards: 200.0, step: 56368
# avg rewards: 197.98
# running episode: 19
# rewards: 200.0, step: 56568
# avg rewards: 197.98
# running episode: 20
# rewards: 200.0, step: 56768
# avg rewards: 197.98
# running episode: 1
# rewards: 200.0, step: 56968
# avg rewards: 197.98
# running episode: 2
# rewards: 200.0, step: 57168
# avg rewards: 197.98
# running episode: 3
# rewards: 200.0, step: 57368
# avg rewards: 197.98
# running episode: 4
# rewards: 200.0, step: 57568
# avg rewards: 197.98
# running episode: 5
# rewards: 200.0, step: 57768
# avg rewards: 197.98
# running episode: 6
# rewards: 200.0, step: 57968
# avg rewards: 197.98
# running episode: 7
# rewards: 200.0, step: 58168
# avg rewards: 197.98
# running episode: 8
# rewards: 200.0, step: 58368
# avg rewards: 197.98
# running episode: 9
# rewards: 200.0, step: 58568
# avg rewards: 197.98
# running episode: 10
# rewards: 200.0, step: 58768
# avg rewards: 197.98
# running episode: 11
# rewards: 200.0, step: 58968
# avg rewards: 197.98
# running episode: 12
# rewards: 200.0, step: 59168
# avg rewards: 197.98
# running episode: 13
# rewards: 200.0, step: 59368
# avg rewards: 197.98
# running episode: 14
# rewards: 200.0, step: 59568
# avg rewards: 197.98
# running episode: 15
# rewards: 200.0, step: 59768
# avg rewards: 197.98
# running episode: 16
# rewards: 200.0, step: 59968
# avg rewards: 197.98
# running episode: 17
# rewards: 200.0, step: 60168
# avg rewards: 197.98
# running episode: 18
# rewards: 200.0, step: 60368
# avg rewards: 197.98
# running episode: 19
# rewards: 200.0, step: 60568
# avg rewards: 197.98
# running episode: 20
# rewards: 200.0, step: 60768
# avg rewards: 197.98
# running episode: 1
# rewards: 200.0, step: 60968
# avg rewards: 197.98
# running episode: 2
# rewards: 200.0, step: 61168
# avg rewards: 197.98
# running episode: 3
# rewards: 164.0, step: 61332
# avg rewards: 197.62
# running episode: 4
# rewards: 200.0, step: 61532
# avg rewards: 197.62
# running episode: 5
# rewards: 200.0, step: 61732
# avg rewards: 197.62
# running episode: 6
# rewards: 174.0, step: 61906
# avg rewards: 197.36
# running episode: 7
# rewards: 200.0, step: 62106
# avg rewards: 197.36
# running episode: 8
# rewards: 200.0, step: 62306
# avg rewards: 197.36
# running episode: 9
# rewards: 200.0, step: 62506
# avg rewards: 197.36
# running episode: 10
# rewards: 200.0, step: 62706
# avg rewards: 197.36
# running episode: 11
# rewards: 200.0, step: 62906
# avg rewards: 197.36
# running episode: 12
# rewards: 179.0, step: 63085
# avg rewards: 197.15
# running episode: 13
# rewards: 200.0, step: 63285
# avg rewards: 197.15
# running episode: 14
# rewards: 200.0, step: 63485
# avg rewards: 197.15
# running episode: 15
# rewards: 200.0, step: 63685
# avg rewards: 197.15
# running episode: 16
# rewards: 200.0, step: 63885
# avg rewards: 197.15
# running episode: 17
# rewards: 200.0, step: 64085
# avg rewards: 197.8
# running episode: 18
# rewards: 200.0, step: 64285
# avg rewards: 197.8
# running episode: 19
# rewards: 200.0, step: 64485
# avg rewards: 198.33
# running episode: 20
# rewards: 200.0, step: 64685
# avg rewards: 198.33
# running episode: 1
# rewards: 200.0, step: 64885
# avg rewards: 198.33
# running episode: 2
# rewards: 200.0, step: 65085
# avg rewards: 198.33
# running episode: 3
# rewards: 200.0, step: 65285
# avg rewards: 198.33
# running episode: 4
# rewards: 200.0, step: 65485
# avg rewards: 198.33
# running episode: 5
# rewards: 200.0, step: 65685
# avg rewards: 198.33
# running episode: 6
# rewards: 200.0, step: 65885
# avg rewards: 198.33
# running episode: 7
# rewards: 200.0, step: 66085
# avg rewards: 198.33
# running episode: 8
# rewards: 200.0, step: 66285
# avg rewards: 198.33
# running episode: 9
# rewards: 200.0, step: 66485
# avg rewards: 198.33
# running episode: 10
# rewards: 200.0, step: 66685
# avg rewards: 198.33
# running episode: 11
# rewards: 200.0, step: 66885
# avg rewards: 198.33
# running episode: 12
# rewards: 174.0, step: 67059
# avg rewards: 198.07
# running episode: 13
# rewards: 200.0, step: 67259
# avg rewards: 198.07
# running episode: 14
# rewards: 200.0, step: 67459
# avg rewards: 198.07
# running episode: 15
# rewards: 200.0, step: 67659
# avg rewards: 198.07
# running episode: 16
# rewards: 200.0, step: 67859
# avg rewards: 198.07
# running episode: 17
# rewards: 200.0, step: 68059
# avg rewards: 198.07
# running episode: 18
# rewards: 200.0, step: 68259
# avg rewards: 198.07
# running episode: 19
# rewards: 200.0, step: 68459
# avg rewards: 198.07
# running episode: 20
# rewards: 200.0, step: 68659
# avg rewards: 198.07
# running episode: 1
# rewards: 200.0, step: 68859
# avg rewards: 198.07
# running episode: 2
# rewards: 200.0, step: 69059
# avg rewards: 198.07
# running episode: 3
# rewards: 200.0, step: 69259
# avg rewards: 198.07
# running episode: 4
# rewards: 200.0, step: 69459
# avg rewards: 198.07
# running episode: 5
# rewards: 200.0, step: 69659
# avg rewards: 198.07
# running episode: 6
# rewards: 200.0, step: 69859
# avg rewards: 198.07
# running episode: 7
# rewards: 200.0, step: 70059
# avg rewards: 198.07
# running episode: 8
# rewards: 200.0, step: 70259
# avg rewards: 198.07
# running episode: 9
# rewards: 200.0, step: 70459
# avg rewards: 198.07
# running episode: 10
# rewards: 200.0, step: 70659
# avg rewards: 198.07
# running episode: 11
# rewards: 200.0, step: 70859
# avg rewards: 198.07
# running episode: 12
# rewards: 200.0, step: 71059
# avg rewards: 198.07
# running episode: 13
# rewards: 200.0, step: 71259
# avg rewards: 198.07
# running episode: 14
# rewards: 200.0, step: 71459
# avg rewards: 198.07
# running episode: 15
# rewards: 200.0, step: 71659
# avg rewards: 198.07
# running episode: 16
# rewards: 200.0, step: 71859
# avg rewards: 198.07
# running episode: 17
# rewards: 200.0, step: 72059
# avg rewards: 198.07
# running episode: 18
# rewards: 200.0, step: 72259
# avg rewards: 198.07
# running episode: 19
# rewards: 200.0, step: 72459
# avg rewards: 198.07
# running episode: 20
# rewards: 200.0, step: 72659
# avg rewards: 198.07
# running episode: 1
# rewards: 200.0, step: 72859
# avg rewards: 198.07
# running episode: 2
# rewards: 200.0, step: 73059
# avg rewards: 198.07
# running episode: 3
# rewards: 200.0, step: 73259
# avg rewards: 198.07
# running episode: 4
# rewards: 200.0, step: 73459
# avg rewards: 198.42
# running episode: 5
# rewards: 200.0, step: 73659
# avg rewards: 198.42
# running episode: 6
# rewards: 200.0, step: 73859
# avg rewards: 198.42
# running episode: 7
# rewards: 200.0, step: 74059
# avg rewards: 198.42
# running episode: 8
# rewards: 200.0, step: 74259
# avg rewards: 198.42
# running episode: 9
# rewards: 200.0, step: 74459
# avg rewards: 198.6
# running episode: 10
# rewards: 200.0, step: 74659
# avg rewards: 198.6
# running episode: 11
# rewards: 200.0, step: 74859
# avg rewards: 198.77
# running episode: 12
# rewards: 200.0, step: 75059
# avg rewards: 198.77
# running episode: 13
# rewards: 200.0, step: 75259
# avg rewards: 198.77
# running episode: 14
# rewards: 200.0, step: 75459
# avg rewards: 198.91
# running episode: 15
# rewards: 200.0, step: 75659
# avg rewards: 198.91
# running episode: 16
# rewards: 200.0, step: 75859
# avg rewards: 198.91
# running episode: 17
# rewards: 200.0, step: 76059
# avg rewards: 198.91
# running episode: 18
# rewards: 200.0, step: 76259
# avg rewards: 198.91
# running episode: 19
# rewards: 200.0, step: 76459
# avg rewards: 198.91
# running episode: 20
# rewards: 200.0, step: 76659
# avg rewards: 198.91
# [182.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0, 200.0]
# Average reward of 20 episodes is:
# 199.1
